# %%
import pyfits as pfimport numpy as np

# %%
f1 = pf.open("trainning2/x/galexj1717pl6757/uc040042.fits")f2 = pf.open("good.fits")hdu1 = f1[1]hdu2 = f2[1]data1 = hdu1.datadata2 = hdu2.datax1 = data1["WAVE"]y1 = data1["FLUX"]x2 = data2["WAVE"]y2 = data2["FLUX"]

# %%
plot(x1, y1)

# %%
plot(x2, y2)

# %%
z = !./fitfits good.fits

# %%
z_string = z[0].split(',')[1:]z_float = [float(x) for x in z_string]z_floatz_float.reverse()z_float
# Out:
# [2.07693196e-09, -2.83814261e-05, 0.044687409, 568.058716, -1225319.88]

# %%
p = np.poly1d(z_float)y2_normalized = y2/p(x2)

# %%
plot(x2,y2_normalized  )

# %%
np.median(y2_normalized[:100])
# Out:
# 0.98808598673357539

# %%
np.median(y1[:100])
# Out:
# 251.31179809570312

# %%
import ab_normal as ab

# %%
reload(ab)
# Out:
# <module 'ab_normal' from 'ab_normal.py'>

# %%
from glob import glob

# %%
fits = glob('trainning2/*/*/*.fits')

# %%
import os

# %%
normalized = [ab.is_normalized(ab.get_flux(f)) for f in fits[:100]]

# %%
ab_normal = [os.path.split(fits[i])[0] for i, x in enumerate(normalized) if not x]

# %%
ab_normal
# Out:
# ['trainning2/9/ntpeg']

# %%
ab.create_dir("ab_normal")

# %%
import shutil as sh

# %%
ab.move('trainning2/9/ntpeg.png', 'ab_normal')
# Out:
# True

# %%
dest = 'ab_normal'

# %%
[ab.move(d, dest) for d in ab_normal]
# Out:
# [True, True, True]

# %%
png_src = [i + '.png' for i in ab_normal]png_dest = [i.replace('trainning2','ab_normal') for i in png_src]

# %%
[ ab.move(s + '.png', (s + '.png').replace('trainning2','ab_normal')) for s in ab_normal]
# Out:
# Could not move  dir!
# [None]

# %%
ab.move(png_src[0], png_dest[0])
# Out:
# Could not move  dir!

# %%
png_src[0], png_dest[0]
# Out:
# ('trainning2/9/ntpeg.png', 'ab_normal/9/ntpeg.png')

# %%
('1' + '2').replace('1','3')
# Out:
# '32'

# %% [markdown]
# ## # check short exposition time

# %%
import pyfits as pfdef get_exposition(file):    f = pf.open(file)    hdu = f[0]    data = hdu.header    return data["EXPTIME"]

# %%
from glob import globfits =  glob('training3/*/' + '*/*.fits')

# %%
','.join( fits[0].split('/')[1:]) # not used, wanted to have table with category and stars
# Out:
# '0,epscas,tg160068.fits'

# %%
exp_times = [get_exposition(f) for f in fits]

# %%
from pandas import *df = DataFrame(exp_times, columns = ['Exposition'])

# %%
stats = df.describe()stats.to_html()
# Out:
# '<table border="1">\n  <thead>\n    <tr>\n      <th></th>\n      <th>Exposition</th>\n    </tr>\n  </thead>\n  <tbody>\n    <tr>\n      <td><strong>count</strong></td>\n      <td>  7664.000000</td>\n    </tr>\n    <tr>\n      <td><strong>mean</strong></td>\n      <td>  1334.150350</td>\n    </tr>\n    <tr>\n      <td><strong>std</strong></td>\n      <td>  1374.144443</td>\n    </tr>\n    <tr>\n      <td><strong>min</strong></td>\n      <td>     0.092000</td>\n    </tr>\n    <tr>\n      <td><strong>25%</strong></td>\n      <td>   313.301000</td>\n    </tr>\n    <tr>\n      <td><strong>50%</strong></td>\n      <td>   900.000000</td>\n    </tr>\n    <tr>\n      <td><strong>75%</strong></td>\n      <td>  1800.000000</td>\n    </tr>\n    <tr>\n      <td><strong>max</strong></td>\n      <td> 21700.191000</td>\n    </tr>\n  </tbody>\n</table>'

# %%
len(df[df.Exposition > 500])
# Out:
# 5094

# %%
len(df[df.Exposition <= 500])
# Out:
# 2570

# %%
import osa = [os.path.split(fits[i]) for i in [0,1,2]]

# %%
import numpy as np

# %%
b = np.array(a)

# %%
import shutil as sh

# %%
sh.copy('training4/0/16peg/tg060031.fits', 'short_exposition/0/16peg/tg060031.fits')

# %%
os.makedirs('short_exposition/0/16peg/')
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# /home/jarousek/projects/thesisReloaded/ab_normal/<ipython-input-164-f1342d16832f> in <module>()
# ----> 1 os.makedirs('short_exposition/0/16peg/')
#
# /usr/lib/python2.7/os.pyc in makedirs(name, mode)
#     155         if tail == curdir:           # xxx/newdir/. exists if xxx/newdir exists
#     156             return
# --> 157     mkdir(name, mode)
#     158
#     159 def removedirs(name):
#
# OSError: [Errno 17] File exists: 'short_exposition/0/16peg/'

# %%
fits
# Out:
# ['training3/9/48lib/ub230059.fits', 'training3/9/the1oriD/oj110054.fits', 'training3/9/v1339aql/tj290002.fits', 'training3/9/hd20899/ti050072.fits', 'training3/9/228eri/tj290048.fits', 'training3/9/hd21455/ti300082.fits', 'training3/9/hd154689/qc160053.fits', 'training3/9/hd20566/va300055.fits', 'training3/9/hd20566/vc150059.fits', 'training3/9/hd203374/ue130018.fits', 'training3/9/hd203374/tj300010.fits', 'training3/9/hd239601/ug080052.fits', 'training3/9/becap/tg060018.fits', 'training3/9/becap/tg120021.fits', 'training3/9/hd20134/ud180021.fits', 'training3/9/hd197434/ue250013.fits', 'training3/9/hip3709/ti300040.fits', 'training3/9/hd180398/tg060023.fits', 'training3/9/v818cas/uh260033.fits', 'training3/9/hd189689/tg060014.fits', 'training3/9/hd37330/ui280067.fits', 'training3/9/hd44996/uc040013.fits', 'training3/9/v4024sgr/ti300017.fits', 'training3/9/hd174886/uh240008.fits', 'training3/9/v2491cyg/rd270034.fits', 'training3/9/v2491cyg/rd270033.fits', 'training3/9/hd26398/uh280025.fits', 'training3/9/hd26398/uh290027.fits', 'training3/9/hip117700/uh220057.fits', 'training3/9/hd22648/qd250013.fits', 'training3/9/hd42406/ui120043.fits', 'training3/9/v771cas/ti160018.fits', 'training3/9/hd205551/tg060030.fits', 'training3/9/8lacA/tg060035.fits', 'training3/9/v416aur/uj160055.fits', 'training3/9/hd173371/ub240083.fits', 'training3/9/kyand/tg060034.fits', 'training3/9/hzaqr/sg310015.fits', 'training3/9/hzaqr/sg310016.fits', 'training3/9/1pup/uj150065.fits', 'training3/9/hip97275/tg060020.fits', 'training3/9/hd47054/tj290073.fits', 'training3/9/v420pup/uk120091.fits', 'training3/9/hd173292/tg120013.fits', 'training3/9/hd168135/ud200059.fits', 'training3/9/v2135cyg/ue250024.fits', 'training3/9/hd23800/tj300037.fits', 'training3/9/hd284012/ti300045.fits', 'training3/9/hd175511/tg060011.fits', 'training3/9/v750mon/vc150023.fits', 'training3/9/hd21641/tj300035.fits', 'training3/9/hd192445/ug080039.fits', 'training3/9/rwaur/vc200017.fits', 'training3/9/v1372ori/ul140018.fits', 'training3/9/v1308ori/ui300027.fits', 'training3/9/delsco/rd260059.fits', 'training3/9/delsco/re250021.fits', 'training3/9/delsco/nc300035.fits', 'training3/9/delsco/md190020.fits', 'training3/9/delsco/rf020032.fits', 'training3/9/delsco/sh070011.fits', 'training3/9/delsco/rf220007.fits', 'training3/9/delsco/re060027.fits', 'training3/9/delsco/ug110011.fits', 'training3/9/delsco/re080032.fits', 'training3/9/delsco/rd260051.fits', 'training3/9/delsco/qg070014.fits', 'training3/9/delsco/re060026.fits', 'training3/9/delsco/od210051.fits', 'training3/9/delsco/ug060027.fits', 'training3/9/delsco/re080033.fits', 'training3/9/delsco/mg130012.fits', 'training3/9/delsco/re060039.fits', 'training3/9/delsco/qg070021.fits', 'training3/9/delsco/rd240030.fits', 'training3/9/delsco/rf020034.fits', 'training3/9/delsco/ug080012.fits', 'training3/9/delsco/oe110021.fits', 'training3/9/delsco/rf020019.fits', 'training3/9/delsco/ue080042.fits', 'training3/9/delsco/re250020.fits', 'training3/9/delsco/rc300042.fits', 'training3/9/delsco/rc290043.fits', 'training3/9/delsco/qg070015.fits', 'training3/9/delsco/sd090032.fits', 'training3/9/delsco/rd240029.fits', 'training3/9/delsco/sh070008.fits', 'training3/9/delsco/re070016.fits', 'training3/9/delsco/vc160098.fits', 'training3/9/delsco/sf200007.fits', 'training3/9/delsco/nc300033.fits', 'training3/9/delsco/mg160011.fits', 'training3/9/delsco/pd210025.fits', 'training3/9/delsco/rf230022.fits', 'training3/9/delsco/re070015.fits', 'training3/9/delsco/rd260042.fits', 'training3/9/delsco/qg070022.fits', 'training3/9/delsco/sf200006.fits', 'training3/9/delsco/uc070048.fits', 'training3/9/delsco/rd260041.fits', 'training3/9/delsco/rf020020.fits', 'training3/9/delsco/ue010025.fits', 'training3/9/delsco/tc240038.fits', 'training3/9/delsco/sf130013.fits', 'training3/9/delsco/ug090012.fits', 'training3/9/delsco/re060038.fits', 'training3/9/delsco/sd100032.fits', 'training3/9/delsco/rf220006.fits', 'training3/9/delsco/rf020033.fits', 'training3/9/d ...
